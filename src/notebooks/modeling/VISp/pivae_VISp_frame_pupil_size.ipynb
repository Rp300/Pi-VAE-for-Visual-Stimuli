# %%
import sys
utils = "/Users/rp/Desktop/Research/CN^3/Thesis Material/2-Region-Latent-Alignment/src"
if utils not in sys.path:
    sys.path.append(utils)

from utils.file_utils import add_project_dirs_to_path

# Add project root and src directory to Python path
add_project_dirs_to_path()

# Standard library imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# Import from project modules
# from pi_vae.pi_vae import *
# from pi_vae.util import *
from modeling.vae_model import *
from utils.data_processing import *
from utils.plotting import *

# Import Keras callback
from keras.callbacks import ModelCheckpoint

# Import plot packages
from matplotlib.ticker import FormatStrFormatter
from matplotlib import ticker
import seaborn

# Suppress warnings
warnings.filterwarnings("ignore")

# Autoreload modules
# %load_ext autoreload
# %autoreload 2

# Show plots inline
# %matplotlib inline
# Out:
# 2024-04-02 14:29:22.143716: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Introduction
#
# - This notebook will focus primarily on the visual cortex, because there is a stronger signal to noise ratio for purely visual behavior variables.
# - Additionally, I have been spooked to look at each brain region independently
# - Also go spooked that there are outliers in the kinematics information (Velocity, position, total distance)

# %%
VERSION = 1
LATENT_DIM = 10
RANDOM_SEED = 999
BRAIN_REGIONS = ['CA1', 'VISp']
MODEL_TYPES = ['vae', 'pivae']

# %% [markdown]
# ### Extract data

# %%
ecephys_session_id = 766640955
brain_region = BRAIN_REGIONS[1]

spike_count_pivot, behavior_data_df = extract_data(ecephys_session_id, brain_region)

# %% [markdown]
# ## Workflows

# %% [markdown]
# ### Pi-VAE - X_v, F, P

# %% [markdown]
# #### Transform Data

# %%
selected_behavior_vars = ['frame', 'pupil_size']

x_all, u_all = transform_data(spike_count_pivot, behavior_data_df, selected_behavior_vars)

# %% [markdown]
# #### Load Data

# %%
x_train, u_train, x_valid, u_valid, x_test, u_test = load_data(x_all=x_all, u_all=u_all)

# %%
model_chk_path, workflow_name = get_model_paths(brain_region=brain_region,
                                    selected_behavior_vars=selected_behavior_vars, 
                                    latent_dim=LATENT_DIM, 
                                    random_seed=RANDOM_SEED, 
                                    model_type=MODEL_TYPES[1]);

print(f"Workflow Name: {workflow_name}")
# Out:
# Workflow Name: pivae_10d_999_VISp_frame_pupil_size

# %%
# Initialize model
vae = initialize_model(dim_x=x_all[0].shape[-1], 
                       dim_z=LATENT_DIM,
                       dim_u=u_all[0].shape[-1], 
                       gen_nodes=60, n_blk=2, mdl='poisson', disc=False, learning_rate=5e-4, random_seed=RANDOM_SEED)

# Train model
s_n = train_model(vae, x_train, u_train, x_valid, u_valid, model_chk_path)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "vae"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 49)]                 0         []
#
#  input_3 (InputLayer)        [(None, 2)]                  0         []
#
#  encoder (Functional)        [(None, 10),                 15440     ['input_1[0][0]',
#                               (None, 10),                            'input_3[0][0]']
#                               (None, 10),
#                               (None, 10),
#                               (None, 10),
#                               (None, 10),
#                               (None, 10)]
#
#  decoder (Functional)        (None, 49)                   15265     ['encoder[0][2]']
#
#  tf.math.subtract_2 (TFOpLa  (None, 10)                   0         ['encoder[0][0]',
#  mbda)                                                               'encoder[0][5]']
#
#  tf.math.square (TFOpLambda  (None, 10)                   0         ['tf.math.subtract_2[0][0]']
#  )
#
#  tf.math.exp (TFOpLambda)    (None, 10)                   0         ['encoder[0][1]']
#
#  tf.__operators__.add (TFOp  (None, 10)                   0         ['encoder[0][1]']
#  Lambda)
#
#  tf.__operators__.add_1 (TF  (None, 10)                   0         ['tf.math.square[0][0]',
#  OpLambda)                                                           'tf.math.exp[0][0]']
#
#  tf.math.exp_1 (TFOpLambda)  (None, 10)                   0         ['encoder[0][6]']
#
#  tf.math.log (TFOpLambda)    (None, 49)                   0         ['decoder[0][0]']
#
#  tf.math.subtract_1 (TFOpLa  (None, 10)                   0         ['tf.__operators__.add[0][0]',
#  mbda)                                                               'encoder[0][6]']
#
#  tf.math.truediv (TFOpLambd  (None, 10)                   0         ['tf.__operators__.add_1[0][0]
#  a)                                                                 ',
#                                                                      'tf.math.exp_1[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 49)                   0         ['input_1[0][0]',
#  da)                                                                 'tf.math.log[0][0]']
#
#  tf.math.subtract_3 (TFOpLa  (None, 10)                   0         ['tf.math.subtract_1[0][0]',
#  mbda)                                                               'tf.math.truediv[0][0]']
#
#  tf.math.subtract (TFOpLamb  (None, 49)                   0         ['decoder[0][0]',
#  da)                                                                 'tf.math.multiply[0][0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None,)                      0         ['tf.math.subtract_3[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum (TFOpLa  (None,)                      0         ['tf.math.subtract[0][0]']
#  mbda)
#
#  tf.math.multiply_1 (TFOpLa  (None,)                      0         ['tf.math.reduce_sum_1[0][0]']
#  mbda)
#
#  tf.__operators__.add_2 (TF  (None,)                      0         ['tf.math.reduce_sum[0][0]',
#  OpLambda)                                                           'tf.math.multiply_1[0][0]']
#
#  tf.math.reduce_mean (TFOpL  ()                           0         ['tf.__operators__.add_2[0][0]
#  ambda)                                                             ']
#
#  add_loss (AddLoss)          ()                           0         ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 30705 (119.94 KB)
# Trainable params: 30705 (119.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 48/48 [==============================] - 12s 43ms/step - loss: 30.1205 - val_loss: 25.9220
# Epoch 2/50
# 48/48 [==============================] - 1s 25ms/step - loss: 23.8532 - val_loss: 25.0824
# Epoch 3/50
# 48/48 [==============================] - 1s 28ms/step - loss: 23.4498 - val_loss: 24.8969
# Epoch 4/50
# 48/48 [==============================] - 1s 31ms/step - loss: 23.2594 - val_loss: 24.6853
# Epoch 5/50
# 48/48 [==============================] - 2s 33ms/step - loss: 22.9916 - val_loss: 24.4493
# Epoch 6/50
# 48/48 [==============================] - 2s 32ms/step - loss: 22.6566 - val_loss: 24.2051
# Epoch 7/50
# 48/48 [==============================] - 2s 30ms/step - loss: 22.4621 - val_loss: 24.1110
# Epoch 8/50
# 48/48 [==============================] - 1s 27ms/step - loss: 22.3817 - val_loss: 24.0295
# Epoch 9/50
# 48/48 [==============================] - 1s 30ms/step - loss: 22.3347 - val_loss: 23.9902
# Epoch 10/50
# 48/48 [==============================] - 2s 36ms/step - loss: 22.2861 - val_loss: 23.9705
# Epoch 11/50
# 48/48 [==============================] - 1s 27ms/step - loss: 22.2600 - val_loss: 23.9356
# Epoch 12/50
# 48/48 [==============================] - 1s 29ms/step - loss: 22.2179 - val_loss: 23.9113
# Epoch 13/50
# 48/48 [==============================] - 1s 30ms/step - loss: 22.1931 - val_loss: 23.8696
# Epoch 14/50
# 48/48 [==============================] - 2s 35ms/step - loss: 22.1556 - val_loss: 23.8203
# Epoch 15/50
# 48/48 [==============================] - 2s 33ms/step - loss: 22.1128 - val_loss: 23.7549
# Epoch 16/50
# 48/48 [==============================] - 2s 36ms/step - loss: 22.0515 - val_loss: 23.6555
# Epoch 17/50
# 48/48 [==============================] - 2s 34ms/step - loss: 22.0023 - val_loss: 23.6009
# Epoch 18/50
# 48/48 [==============================] - 2s 40ms/step - loss: 21.9741 - val_loss: 23.5433
# Epoch 19/50
# 48/48 [==============================] - 2s 32ms/step - loss: 21.9264 - val_loss: 23.4898
# Epoch 20/50
# 48/48 [==============================] - 2s 34ms/step - loss: 21.8951 - val_loss: 23.4497
# Epoch 21/50
# 48/48 [==============================] - 2s 32ms/step - loss: 21.8496 - val_loss: 23.3642
# Epoch 22/50
# 48/48 [==============================] - 2s 33ms/step - loss: 21.8206 - val_loss: 23.3050
# Epoch 23/50
# 48/48 [==============================] - 2s 41ms/step - loss: 21.7926 - val_loss: 23.2891
# Epoch 24/50
# 48/48 [==============================] - 2s 34ms/step - loss: 21.7631 - val_loss: 23.2164
# Epoch 25/50
# 48/48 [==============================] - 2s 40ms/step - loss: 21.7427 - val_loss: 23.2060
# Epoch 26/50
# 48/48 [==============================] - 2s 41ms/step - loss: 21.7160 - val_loss: 23.1357
# Epoch 27/50
# 48/48 [==============================] - 2s 34ms/step - loss: 21.6942 - val_loss: 23.1383
# Epoch 28/50
# 48/48 [==============================] - 2s 34ms/step - loss: 21.6707 - val_loss: 23.1099
# Epoch 29/50
# 48/48 [==============================] - 2s 35ms/step - loss: 21.6345 - val_loss: 23.0742
# Epoch 30/50
# 48/48 [==============================] - 2s 42ms/step - loss: 21.6280 - val_loss: 23.0438
# Epoch 31/50
# 48/48 [==============================] - 2s 35ms/step - loss: 21.5986 - val_loss: 23.0259
# Epoch 32/50
# 48/48 [==============================] - 2s 34ms/step - loss: 21.5866 - val_loss: 23.0178
# Epoch 33/50
# 48/48 [==============================] - 2s 33ms/step - loss: 21.5495 - val_loss: 22.9692
# Epoch 34/50
# 48/48 [==============================] - 2s 42ms/step - loss: 21.5406 - val_loss: 22.9376
# Epoch 35/50
# 48/48 [==============================] - 2s 33ms/step - loss: 21.5182 - val_loss: 22.9641
# Epoch 36/50
# 48/48 [==============================] - 2s 43ms/step - loss: 21.4974 - val_loss: 22.9392
# Epoch 37/50
# 48/48 [==============================] - 2s 44ms/step - loss: 21.4925 - val_loss: 22.9355
# Epoch 38/50
# 48/48 [==============================] - 2s 38ms/step - loss: 21.4757 - val_loss: 22.9241
# Epoch 39/50
# 48/48 [==============================] - 2s 50ms/step - loss: 21.4742 - val_loss: 22.9117
# Epoch 40/50
# 48/48 [==============================] - 2s 49ms/step - loss: 21.4513 - val_loss: 22.8886
# Epoch 41/50
# 48/48 [==============================] - 2s 42ms/step - loss: 21.4480 - val_loss: 22.8993
# Epoch 42/50
# 48/48 [==============================] - 3s 58ms/step - loss: 21.4329 - val_loss: 22.8809
# Epoch 43/50
# 48/48 [==============================] - 3s 55ms/step - loss: 21.4134 - val_loss: 22.8721
# Epoch 44/50
# 48/48 [==============================] - 2s 47ms/step - loss: 21.3982 - val_loss: 22.8323
# Epoch 45/50
# 48/48 [==============================] - 2s 40ms/step - loss: 21.3914 - val_loss: 22.8515
# Epoch 46/50
# 48/48 [==============================] - 2s 47ms/step - loss: 21.3870 - val_loss: 22.8169
# Epoch 47/50
# 48/48 [==============================] - 2s 50ms/step - loss: 21.3616 - val_loss: 22.8242
# Epoch 48/50
# 48/48 [==============================] - 3s 53ms/step - loss: 21.3474 - val_loss: 22.8136
# Epoch 49/50
# 48/48 [==============================] - 2s 40ms/step - loss: 21.3436 - val_loss: 22.8203
# Epoch 50/50
# 48/48 [==============================] - 3s 55ms/step - loss: 21.3457 - val_loss: 22.8044

# %%
plot_validation_loss(s_n, workflow_name, VERSION, save_plot=False, show_plot=True)

# %%
outputs = inference(vae, x_all, u_all, model_chk_path) # post_mean, post_log_var, z_sample,fire_rate, lam_mean, lam_log_var, z_mean, z_log_var

# %% [markdown]
# ##### TODO: clean/Package this variance compute and sort code

# %%
# Calculate variances of all columns of outputs[0]
variances = outputs[0].var(axis=0)

# Sort the columns by variance in descending order and get the indices
sorted_indices = np.argsort(variances)[::-1]

# Create a new object containing the columns of outputs[0] sorted by variance
sorted_outputs = outputs[0][:, sorted_indices]

print(sorted_outputs.var(axis=0))
# Out:
# [1.0399207  0.52252084 0.30492678 0.28603226 0.15462059 0.09206648
#  0.06473371 0.04800906 0.04265251 0.02502159]

# %% [markdown]
# #### Plotting

# %%
save_plot = False

plot_single_latent_trajectory(outputs, sorted_indices, workflow_name, save_plot=save_plot, save_dir=None, show_plot=True)
# Out:
# Latent 1 idx: 9
# Latent 2 idx: 1

# %%
save_plot = False

plot_dir = get_plot_dir(workflow_name, version_number=VERSION, plot_type='latent')

plot_multi_latent_trajectory(outputs, sorted_indices, workflow_name, num_stims=15, save_plot=save_plot, save_dir=plot_dir, show_plot=True)
# Out:
# Latent 1 idx: 9
# Latent 2 idx: 1
